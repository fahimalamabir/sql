# %% [markdown]
# First create a database by right clicking database,
# ![image.png](attachment:image.png)
# Then import the csv file by right clicking on the newly created database and then select tasks and then add flat file. The table name is 'eurovis'.

# %% [raw]
# SELECT
#   country
# FROM
#   eurovis;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Use TOP to change the query so that only the first 5 rows are returned.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Return a list of unique countries using DISTINCT. Give the results an alias of unique_country.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# SELECT the country and event_year columns from the eurovis table.

# %% [raw]
# -- Select country and event_year from eurovision
# SELECT
#   country,
#   EventYear
# FROM
#   eurovis;

# %% [markdown]
# ![image.png](attachment:image.png)
# Use a shortcut to amend the current query, returning ALL rows from ALL columns in the table.

# %% [raw]
# -- Amend the code to select all rows and columns
# SELECT *
# FROM
#   eurovis;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This time, restrict the rows to the first half using 'PERCENT', using the same shortcut as before to return all columns.

# %% [raw]
# -- Return all columns, restricting the percent of rows returned
# SELECT
#   TOP (50) PERCENT *
# FROM
#   eurovis;

# %% [markdown]
# Top three rows.

# %% [raw]
# SELECT TOP 3 * FROM eurovis;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# SELECT TOP 3 * FROM eurovis
# WHERE HostRegion='Home';

# %% [markdown]
# ![image.png](attachment:image.png)
